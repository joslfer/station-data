# %% [markdown]
# # Big era exploration: 2001-2023
#
# Now that we have our dataset with more than 1,2 million rows, let's make sure that the data is correct. I'm going to name this era "big era" because there isn't going to be a bigger one in this project.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('../src')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 


from loaders import *

# %%
df = load_range(2000,1,2023,2)

# %%
df

# %%
print(df.head())

# %% [markdown]
# Some tests:

# %%
df["date"].duplicated().sum()
print(df[df["date"].duplicated(keep=False)])
len(df)


# There are no duplicates, because we have removed them

# %%
df_isna = df.isna().groupby(df["date"].dt.year).sum()

df_isna

# %%
df_2000 = df[df["date"].dt.year == 2000]
df_2000["temp"].isna().sum()

# %%
df_2000[df_2000["temp"].notna()]["date"].min()

# %%
df_2000.isna().groupby(df_2000["date"].dt.month).sum()
